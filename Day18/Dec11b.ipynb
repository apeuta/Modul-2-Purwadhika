# %% [markdown]
# ### READ IMAGE on PLOTLIB

# %%
import matplotlib.image as mimg
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
gbr = mimg.imread("reddevil.png")[:,:,2]
gbr.shape
# Out:
# (1000, 652)

# %%
plt.imshow(gbr, cmap="hot")
plt.colorbar()
plt.show()
